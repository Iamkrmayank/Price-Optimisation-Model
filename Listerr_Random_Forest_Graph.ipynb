# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/Users/kumarmayank/Downloads/Dataset_modified_pom.csv')

# %%
df = df.drop(['Product Availibility index','City'],axis=1)

# %%
c
# Out:
# /var/folders/rw/z1h7_zz967sf8xy_601yr3cw0000gn/T/ipykernel_10637/1124908124.py:10: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
