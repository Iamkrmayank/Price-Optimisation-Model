# %%
from google.colab import files
files.upload()

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("Dataset_modified_pom.xlsx")

# %%
df = df.drop(['Product Availibility index','City'],axis=1)

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Assuming df_resampled is already created and has 'Date', 'MRP', 'SP', and 'MSP' columns

# Calculate the median for each time series for each date
median_values = df_resampled.groupby(df_resampled.index)['MRP', 'SP', 'MSP'].median()

# Create the scatter plot
plt.figure(figsize=(12, 8))

# Scatter plot for MRP
plt.scatter(median_values.index, median_values['MRP'], label='Median MRP', color='red')

# Scatter plot for SP
plt.scatter(median_values.index, median_values['SP'], label='Median SP', color='green')

# Scatter plot for MSP
plt.scatter(median_values.index, median_values['MSP'], label='Median MSP', color='blue')

# Add labels and title
plt.xlabel('Date')
plt.ylabel('Median Price')
plt.title('Scatter Plot of Median MRP, SP, and MSP')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Add legend
plt.legend()

# Show the plot
plt.show()
# Out:
# <ipython-input-7-3c90ca48dd04>:8: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   median_values = df_resampled.groupby(df_resampled.index)['MRP', 'SP', 'MSP'].median()
